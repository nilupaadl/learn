# %% [markdown]
# # Keras Exercise
#
# ## Predict political party based on votes
#
# As a fun little example, we'll use a public data set of how US congressmen voted on 17 different issues in the year 1984. Let's see if we can figure out their political party based on their votes alone, using a deep neural network!
#
# For those outside the United States, our two main political parties are "Democrat" and "Republican." In modern times they represent progressive and conservative ideologies, respectively.
#
# Politics in 1984 weren't quite as polarized as they are today, but you should still be able to get over 90% accuracy without much trouble.
#
# Since the point of this exercise is implementing neural networks in Keras, I'll help you to load and prepare the data.
#
# Let's start by importing the raw CSV file using Pandas, and make a DataFrame out of it with nice column labels:

# %%
import pandas as pd

feature_names =  ['party','handicapped-infants', 'water-project-cost-sharing', 
                    'adoption-of-the-budget-resolution', 'physician-fee-freeze',
                    'el-salvador-aid', 'religious-groups-in-schools',
                    'anti-satellite-test-ban', 'aid-to-nicaraguan-contras',
                    'mx-missle', 'immigration', 'synfuels-corporation-cutback',
                    'education-spending', 'superfund-right-to-sue', 'crime',
                    'duty-free-exports', 'export-administration-act-south-africa']

voting_data = pd.read_csv('house-votes-84.data.txt', na_values=['?'], 
                          names = feature_names)
voting_data.head()
# Out:
#         party handicapped-infants water-project-cost-sharing  \
# 0  republican                   n                          y
# 1  republican                   n                          y
# 2    democrat                 NaN                          y
# 3    democrat                   n                          y
# 4    democrat                   y                          y
#
#   adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                 n                    y               y
# 1                                 n                    y               y
# 2                                 y                  NaN               y
# 3                                 y                    n             NaN
# 4                                 y                    n               y
#
#   religious-groups-in-schools anti-satellite-test-ban  \
# 0                           y                       n
# 1                           y                       n
# 2                           y                       n
# 3                           y                       n
# 4                           y                       n
#
#   aid-to-nicaraguan-contras mx-missle immigration  \
# 0                         n         n           y
# 1                         n         n           n
# 2                         n         n           n
# 3                         n         n           n
# 4                         n         n           n
#
#   synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 0                          NaN                  y                      y
# 1                            n                  y                      y
# 2                            y                  n                      y
# 3                            y                  n                      y
# 4                            y                NaN                      y
#
#   crime duty-free-exports export-administration-act-south-africa
# 0     y                 n                                      y
# 1     y                 n                                    NaN
# 2     y                 n                                      n
# 3     n                 n                                      y
# 4     y                 y                                      y

# %% [markdown]
# We can use describe() to get a feel of how the data looks in aggregate:

# %%
voting_data.describe()
# Out:
#            party handicapped-infants water-project-cost-sharing  \
# count        435                 423                        387
# unique         2                   2                          2
# top     democrat                   n                          y
# freq         267                 236                        195
#
#        adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# count                                424                  424             420
# unique                                 2                    2               2
# top                                    y                    n               y
# freq                                 253                  247             212
#
#        religious-groups-in-schools anti-satellite-test-ban  \
# count                          424                     421
# unique                           2                       2
# top                              y                       y
# freq                           272                     239
#
#        aid-to-nicaraguan-contras mx-missle immigration  \
# count                        420       413         428
# unique                         2         2           2
# top                            y         y           y
# freq                         242       207         216
#
#        synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# count                           414                404                    410
# unique                            2                  2                      2
# top                               n                  n                      y
# freq                            264                233                    209
#
#        crime duty-free-exports export-administration-act-south-africa
# count    418               407                                    331
# unique     2                 2                                      2
# top        y                 n                                      y
# freq     248               233                                    269

# %% [markdown]
# We can see there's some missing data to deal with here; some politicians abstained on some votes, or just weren't present when the vote was taken. We will just drop the rows with missing data to keep it simple, but in practice you'd want to first make sure that doing so didn't introduce any sort of bias into your analysis (if one party abstains more than another, that could be problematic for example.)

# %%
voting_data.dropna(inplace=True)
voting_data.describe()
# Out:
#            party handicapped-infants water-project-cost-sharing  \
# count        232                 232                        232
# unique         2                   2                          2
# top     democrat                   n                          n
# freq         124                 136                        125
#
#        adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# count                                232                  232             232
# unique                                 2                    2               2
# top                                    y                    n               y
# freq                                 123                  119             128
#
#        religious-groups-in-schools anti-satellite-test-ban  \
# count                          232                     232
# unique                           2                       2
# top                              y                       y
# freq                           149                     124
#
#        aid-to-nicaraguan-contras mx-missle immigration  \
# count                        232       232         232
# unique                         2         2           2
# top                            y         n           y
# freq                         119       119         128
#
#        synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# count                           232                232                    232
# unique                            2                  2                      2
# top                               n                  n                      y
# freq                            152                124                    127
#
#        crime duty-free-exports export-administration-act-south-africa
# count    232               232                                    232
# unique     2                 2                                      2
# top        y                 n                                      y
# freq     149               146                                    189

# %% [markdown]
# Our neural network needs normalized numbers, not strings, to work. So let's replace all the y's and n's with 1's and 0's, and represent the parties as 1's and 0's as well.

# %%
voting_data.replace(('y', 'n'), (1, 0), inplace=True)
voting_data.replace(('democrat', 'republican'), (1, 0), inplace=True)

# %%
voting_data.head()
# Out:
#     party  handicapped-infants  water-project-cost-sharing  \
# 5       1                    0                           1
# 8       0                    0                           1
# 19      1                    1                           1
# 23      1                    1                           1
# 25      1                    1                           0
#
#     adoption-of-the-budget-resolution  physician-fee-freeze  el-salvador-aid  \
# 5                                   1                     0                1
# 8                                   0                     1                1
# 19                                  1                     0                0
# 23                                  1                     0                0
# 25                                  1                     0                0
#
#     religious-groups-in-schools  anti-satellite-test-ban  \
# 5                             1                        0
# 8                             1                        0
# 19                            0                        1
# 23                            0                        1
# 25                            0                        1
#
#     aid-to-nicaraguan-contras  mx-missle  immigration  \
# 5                           0          0            0
# 8                           0          0            0
# 19                          1          1            0
# 23                          1          1            0
# 25                          1          1            1
#
#     synfuels-corporation-cutback  education-spending  superfund-right-to-sue  \
# 5                              0                   0                       1
# 8                              0                   1                       1
# 19                             1                   0                       0
# 23                             0                   0                       0
# 25                             0                   0                       0
#
#     crime  duty-free-exports  export-administration-act-south-africa
# 5       1                  1                                       1
# 8       1                  0                                       1
# 19      0                  1                                       1
# 23      0                  1                                       1
# 25      0                  1                                       1

# %% [markdown]
# Finally let's extract the features and labels in the form that Keras will expect:

# %%
all_features = voting_data[feature_names].drop('party', axis=1).values
all_classes = voting_data['party'].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(all_features, all_classes, test_size=0.33, random_state=42)

# %% [markdown]
# OK, so have a go at it! You'll want to refer back to the slide on using Keras with binary classification - there are only two parties, so this is a binary problem. This also saves us the hassle of representing classes with "one-hot" format like we had to do with MNIST; our output is just a single 0 or 1 value.
#
# Also refer to the scikit_learn integration slide, and use cross_val_score to evaluate your resulting model with 10-fold cross-validation.
#
# **If you're using tensorflow-gpu on a Windows machine** by the way, you probably *do* want to peek a little bit at my solution - if you run into memory allocation errors, there's a workaround there you can use.
#
# Try out your code here:

# %%
from tensorflow import keras
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import RMSprop

# %%
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(16,)))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_65 (Dense)             (None, 64)                1088
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_66 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_67 (Dense)             (None, 16)                528
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_68 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 3,713
# Trainable params: 3,713
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train,
                    #batch_size=100,
                    epochs=100,
                    verbose=2,
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 5/5 - 0s - loss: 0.7463 - accuracy: 0.5290 - val_loss: 0.6107 - val_accuracy: 0.8701
# Epoch 2/100
# 5/5 - 0s - loss: 0.6877 - accuracy: 0.6065 - val_loss: 0.5917 - val_accuracy: 0.8831
# Epoch 3/100
# 5/5 - 0s - loss: 0.6853 - accuracy: 0.5548 - val_loss: 0.5738 - val_accuracy: 0.8831
# Epoch 4/100
# 5/5 - 0s - loss: 0.6233 - accuracy: 0.6710 - val_loss: 0.5532 - val_accuracy: 0.9091
# Epoch 5/100
# 5/5 - 0s - loss: 0.6853 - accuracy: 0.5871 - val_loss: 0.5361 - val_accuracy: 0.9091
# Epoch 6/100
# 5/5 - 0s - loss: 0.6446 - accuracy: 0.6387 - val_loss: 0.5207 - val_accuracy: 0.9091
# Epoch 7/100
# 5/5 - 0s - loss: 0.5728 - accuracy: 0.7032 - val_loss: 0.5033 - val_accuracy: 0.9091
# Epoch 8/100
# 5/5 - 0s - loss: 0.5755 - accuracy: 0.7226 - val_loss: 0.4850 - val_accuracy: 0.9091
# Epoch 9/100
# 5/5 - 0s - loss: 0.5571 - accuracy: 0.7032 - val_loss: 0.4695 - val_accuracy: 0.9091
# Epoch 10/100
# 5/5 - 0s - loss: 0.5428 - accuracy: 0.7226 - val_loss: 0.4515 - val_accuracy: 0.9091
# Epoch 11/100
# 5/5 - 0s - loss: 0.5839 - accuracy: 0.6839 - val_loss: 0.4372 - val_accuracy: 0.9221
# Epoch 12/100
# 5/5 - 0s - loss: 0.5025 - accuracy: 0.7419 - val_loss: 0.4233 - val_accuracy: 0.9221
# Epoch 13/100
# 5/5 - 0s - loss: 0.5144 - accuracy: 0.7419 - val_loss: 0.4068 - val_accuracy: 0.9091
# Epoch 14/100
# 5/5 - 0s - loss: 0.4924 - accuracy: 0.7806 - val_loss: 0.3895 - val_accuracy: 0.9091
# Epoch 15/100
# 5/5 - 0s - loss: 0.4708 - accuracy: 0.7419 - val_loss: 0.3720 - val_accuracy: 0.9091
# Epoch 16/100
# 5/5 - 0s - loss: 0.5092 - accuracy: 0.7613 - val_loss: 0.3550 - val_accuracy: 0.9091
# Epoch 17/100
# 5/5 - 0s - loss: 0.4296 - accuracy: 0.7871 - val_loss: 0.3363 - val_accuracy: 0.9221
# Epoch 18/100
# 5/5 - 0s - loss: 0.4548 - accuracy: 0.8129 - val_loss: 0.3191 - val_accuracy: 0.9351
# Epoch 19/100
# 5/5 - 0s - loss: 0.4671 - accuracy: 0.8194 - val_loss: 0.3025 - val_accuracy: 0.9481
# Epoch 20/100
# 5/5 - 0s - loss: 0.4065 - accuracy: 0.8258 - val_loss: 0.2845 - val_accuracy: 0.9481
# Epoch 21/100
# 5/5 - 0s - loss: 0.4021 - accuracy: 0.8452 - val_loss: 0.2666 - val_accuracy: 0.9481
# Epoch 22/100
# 5/5 - 0s - loss: 0.4032 - accuracy: 0.8387 - val_loss: 0.2483 - val_accuracy: 0.9740
# Epoch 23/100
# 5/5 - 0s - loss: 0.4421 - accuracy: 0.8258 - val_loss: 0.2342 - val_accuracy: 0.9740
# Epoch 24/100
# 5/5 - 0s - loss: 0.3331 - accuracy: 0.8839 - val_loss: 0.2211 - val_accuracy: 0.9740
# Epoch 25/100
# 5/5 - 0s - loss: 0.3399 - accuracy: 0.8645 - val_loss: 0.2092 - val_accuracy: 0.9740
# Epoch 26/100
# 5/5 - 0s - loss: 0.4501 - accuracy: 0.8516 - val_loss: 0.1998 - val_accuracy: 0.9610
# Epoch 27/100
# 5/5 - 0s - loss: 0.3922 - accuracy: 0.8581 - val_loss: 0.1933 - val_accuracy: 0.9610
# Epoch 28/100
# 5/5 - 0s - loss: 0.4177 - accuracy: 0.8129 - val_loss: 0.1855 - val_accuracy: 0.9740
# Epoch 29/100
# 5/5 - 0s - loss: 0.3328 - accuracy: 0.8516 - val_loss: 0.1776 - val_accuracy: 0.9740
# Epoch 30/100
# 5/5 - 0s - loss: 0.2981 - accuracy: 0.8839 - val_loss: 0.1689 - val_accuracy: 0.9740
# Epoch 31/100
# 5/5 - 0s - loss: 0.3309 - accuracy: 0.8645 - val_loss: 0.1635 - val_accuracy: 0.9740
# Epoch 32/100
# 5/5 - 0s - loss: 0.3795 - accuracy: 0.8710 - val_loss: 0.1573 - val_accuracy: 0.9740
# Epoch 33/100
# 5/5 - 0s - loss: 0.3121 - accuracy: 0.8581 - val_loss: 0.1525 - val_accuracy: 0.9740
# Epoch 34/100
# 5/5 - 0s - loss: 0.3065 - accuracy: 0.8839 - val_loss: 0.1483 - val_accuracy: 0.9740
# Epoch 35/100
# 5/5 - 0s - loss: 0.2945 - accuracy: 0.9032 - val_loss: 0.1469 - val_accuracy: 0.9740
# Epoch 36/100
# 5/5 - 0s - loss: 0.3339 - accuracy: 0.8645 - val_loss: 0.1463 - val_accuracy: 0.9610
# Epoch 37/100
# 5/5 - 0s - loss: 0.3025 - accuracy: 0.8903 - val_loss: 0.1459 - val_accuracy: 0.9610
# Epoch 38/100
# 5/5 - 0s - loss: 0.2759 - accuracy: 0.9355 - val_loss: 0.1427 - val_accuracy: 0.9610
# Epoch 39/100
# 5/5 - 0s - loss: 0.2554 - accuracy: 0.9290 - val_loss: 0.1404 - val_accuracy: 0.9610
# Epoch 40/100
# 5/5 - 0s - loss: 0.3273 - accuracy: 0.8839 - val_loss: 0.1424 - val_accuracy: 0.9610
# Epoch 41/100
# 5/5 - 0s - loss: 0.2598 - accuracy: 0.8774 - val_loss: 0.1383 - val_accuracy: 0.9610
# Epoch 42/100
# 5/5 - 0s - loss: 0.2555 - accuracy: 0.8903 - val_loss: 0.1336 - val_accuracy: 0.9610
# Epoch 43/100
# 5/5 - 0s - loss: 0.2290 - accuracy: 0.9226 - val_loss: 0.1323 - val_accuracy: 0.9610
# Epoch 44/100
# 5/5 - 0s - loss: 0.2279 - accuracy: 0.9290 - val_loss: 0.1323 - val_accuracy: 0.9610
# Epoch 45/100
# 5/5 - 0s - loss: 0.2239 - accuracy: 0.9161 - val_loss: 0.1315 - val_accuracy: 0.9610
# Epoch 46/100
# 5/5 - 0s - loss: 0.2355 - accuracy: 0.9032 - val_loss: 0.1320 - val_accuracy: 0.9610
# Epoch 47/100
# 5/5 - 0s - loss: 0.1907 - accuracy: 0.9161 - val_loss: 0.1319 - val_accuracy: 0.9481
# Epoch 48/100
# 5/5 - 0s - loss: 0.2893 - accuracy: 0.8903 - val_loss: 0.1286 - val_accuracy: 0.9481
# Epoch 49/100
# 5/5 - 0s - loss: 0.2628 - accuracy: 0.9161 - val_loss: 0.1260 - val_accuracy: 0.9481
# Epoch 50/100
# 5/5 - 0s - loss: 0.2205 - accuracy: 0.9677 - val_loss: 0.1218 - val_accuracy: 0.9481
# Epoch 51/100
# 5/5 - 0s - loss: 0.2248 - accuracy: 0.9355 - val_loss: 0.1148 - val_accuracy: 0.9610
# Epoch 52/100
# 5/5 - 0s - loss: 0.1785 - accuracy: 0.9419 - val_loss: 0.1103 - val_accuracy: 0.9610
# Epoch 53/100
# 5/5 - 0s - loss: 0.2177 - accuracy: 0.9290 - val_loss: 0.1086 - val_accuracy: 0.9610
# Epoch 54/100
# 5/5 - 0s - loss: 0.2470 - accuracy: 0.9355 - val_loss: 0.1062 - val_accuracy: 0.9610
# Epoch 55/100
# 5/5 - 0s - loss: 0.2087 - accuracy: 0.9548 - val_loss: 0.1077 - val_accuracy: 0.9610
# Epoch 56/100
# 5/5 - 0s - loss: 0.2102 - accuracy: 0.9613 - val_loss: 0.1099 - val_accuracy: 0.9610
# Epoch 57/100
# 5/5 - 0s - loss: 0.1561 - accuracy: 0.9613 - val_loss: 0.1116 - val_accuracy: 0.9610
# Epoch 58/100
# 5/5 - 0s - loss: 0.1667 - accuracy: 0.9484 - val_loss: 0.1126 - val_accuracy: 0.9610
# Epoch 59/100
# 5/5 - 0s - loss: 0.1638 - accuracy: 0.9484 - val_loss: 0.1131 - val_accuracy: 0.9610
# Epoch 60/100
# 5/5 - 0s - loss: 0.1596 - accuracy: 0.9419 - val_loss: 0.1097 - val_accuracy: 0.9610
# Epoch 61/100
# 5/5 - 0s - loss: 0.2222 - accuracy: 0.9161 - val_loss: 0.1063 - val_accuracy: 0.9610
# Epoch 62/100
# 5/5 - 0s - loss: 0.1804 - accuracy: 0.9484 - val_loss: 0.1074 - val_accuracy: 0.9610
# Epoch 63/100
# 5/5 - 0s - loss: 0.1403 - accuracy: 0.9548 - val_loss: 0.1129 - val_accuracy: 0.9610
# Epoch 64/100
# 5/5 - 0s - loss: 0.1553 - accuracy: 0.9419 - val_loss: 0.1172 - val_accuracy: 0.9610
# Epoch 65/100
# 5/5 - 0s - loss: 0.1526 - accuracy: 0.9548 - val_loss: 0.1191 - val_accuracy: 0.9481
# Epoch 66/100
# 5/5 - 0s - loss: 0.2095 - accuracy: 0.9419 - val_loss: 0.1190 - val_accuracy: 0.9481
# Epoch 67/100
# 5/5 - 0s - loss: 0.1722 - accuracy: 0.9419 - val_loss: 0.1165 - val_accuracy: 0.9481
# Epoch 68/100
# 5/5 - 0s - loss: 0.1320 - accuracy: 0.9806 - val_loss: 0.1164 - val_accuracy: 0.9481
# Epoch 69/100
# 5/5 - 0s - loss: 0.1162 - accuracy: 0.9613 - val_loss: 0.1179 - val_accuracy: 0.9481
# Epoch 70/100
# 5/5 - 0s - loss: 0.1068 - accuracy: 0.9613 - val_loss: 0.1190 - val_accuracy: 0.9481
# Epoch 71/100
# 5/5 - 0s - loss: 0.2012 - accuracy: 0.9290 - val_loss: 0.1194 - val_accuracy: 0.9481
# Epoch 72/100
# 5/5 - 0s - loss: 0.1178 - accuracy: 0.9677 - val_loss: 0.1204 - val_accuracy: 0.9481
# Epoch 73/100
# 5/5 - 0s - loss: 0.1324 - accuracy: 0.9613 - val_loss: 0.1178 - val_accuracy: 0.9481
# Epoch 74/100
# 5/5 - 0s - loss: 0.1244 - accuracy: 0.9355 - val_loss: 0.1162 - val_accuracy: 0.9610
# Epoch 75/100
# 5/5 - 0s - loss: 0.1477 - accuracy: 0.9419 - val_loss: 0.1103 - val_accuracy: 0.9610
# Epoch 76/100
# 5/5 - 0s - loss: 0.0932 - accuracy: 0.9742 - val_loss: 0.1084 - val_accuracy: 0.9610
# Epoch 77/100
# 5/5 - 0s - loss: 0.1281 - accuracy: 0.9484 - val_loss: 0.1117 - val_accuracy: 0.9610
# Epoch 78/100
# 5/5 - 0s - loss: 0.1283 - accuracy: 0.9677 - val_loss: 0.1149 - val_accuracy: 0.9610
# Epoch 79/100
# 5/5 - 0s - loss: 0.1483 - accuracy: 0.9613 - val_loss: 0.1130 - val_accuracy: 0.9610
# Epoch 80/100
# 5/5 - 0s - loss: 0.1001 - accuracy: 0.9742 - val_loss: 0.1118 - val_accuracy: 0.9610
# Epoch 81/100
# 5/5 - 0s - loss: 0.1778 - accuracy: 0.9355 - val_loss: 0.1154 - val_accuracy: 0.9610
# Epoch 82/100
# 5/5 - 0s - loss: 0.1386 - accuracy: 0.9355 - val_loss: 0.1147 - val_accuracy: 0.9610
# Epoch 83/100
# 5/5 - 0s - loss: 0.1758 - accuracy: 0.9290 - val_loss: 0.1128 - val_accuracy: 0.9610
# Epoch 84/100
# 5/5 - 0s - loss: 0.1566 - accuracy: 0.9548 - val_loss: 0.1085 - val_accuracy: 0.9610
# Epoch 85/100
# 5/5 - 0s - loss: 0.1284 - accuracy: 0.9742 - val_loss: 0.1039 - val_accuracy: 0.9610
# Epoch 86/100
# 5/5 - 0s - loss: 0.1276 - accuracy: 0.9484 - val_loss: 0.1008 - val_accuracy: 0.9610
# Epoch 87/100
# 5/5 - 0s - loss: 0.1269 - accuracy: 0.9677 - val_loss: 0.0960 - val_accuracy: 0.9740
# Epoch 88/100
# 5/5 - 0s - loss: 0.0905 - accuracy: 0.9677 - val_loss: 0.0954 - val_accuracy: 0.9740
# Epoch 89/100
# 5/5 - 0s - loss: 0.1138 - accuracy: 0.9742 - val_loss: 0.0963 - val_accuracy: 0.9740
# Epoch 90/100
# 5/5 - 0s - loss: 0.1253 - accuracy: 0.9613 - val_loss: 0.1001 - val_accuracy: 0.9740
# Epoch 91/100
# 5/5 - 0s - loss: 0.1041 - accuracy: 0.9806 - val_loss: 0.1096 - val_accuracy: 0.9610
# Epoch 92/100
# 5/5 - 0s - loss: 0.1204 - accuracy: 0.9613 - val_loss: 0.1332 - val_accuracy: 0.9351
# Epoch 93/100
# 5/5 - 0s - loss: 0.1162 - accuracy: 0.9613 - val_loss: 0.1592 - val_accuracy: 0.9351
# Epoch 94/100
# 5/5 - 0s - loss: 0.1181 - accuracy: 0.9677 - val_loss: 0.1570 - val_accuracy: 0.9351
# Epoch 95/100
# 5/5 - 0s - loss: 0.1107 - accuracy: 0.9677 - val_loss: 0.1233 - val_accuracy: 0.9610
# Epoch 96/100
# 5/5 - 0s - loss: 0.0977 - accuracy: 0.9548 - val_loss: 0.1052 - val_accuracy: 0.9610
# Epoch 97/100
# 5/5 - 0s - loss: 0.1450 - accuracy: 0.9742 - val_loss: 0.0989 - val_accuracy: 0.9610
# Epoch 98/100
# 5/5 - 0s - loss: 0.1184 - accuracy: 0.9677 - val_loss: 0.1002 - val_accuracy: 0.9610
# Epoch 99/100
# 5/5 - 0s - loss: 0.0930 - accuracy: 0.9548 - val_loss: 0.1020 - val_accuracy: 0.9610
# Epoch 100/100
# 5/5 - 0s - loss: 0.1033 - accuracy: 0.9484 - val_loss: 0.1035 - val_accuracy: 0.9610

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.10354840755462646
# Test accuracy: 0.9610389471054077

# %% [markdown]
# ## My implementation is below
#
# # No peeking!
#
# ![title](peek.jpg)

# %%
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Sequential
from sklearn.model_selection import cross_val_score

def create_model():
    model = Sequential()
    #16 feature inputs (votes) going into an 32-unit layer 
    model.add(Dense(32, input_dim=16, kernel_initializer='normal', activation='relu'))
    # Another hidden layer of 16 units
    model.add(Dense(16, kernel_initializer='normal', activation='relu'))
    # Output layer with a binary classification (Democrat or Republican political party)
    model.add(Dense(1, kernel_initializer='normal', activation='sigmoid'))
    # Compile model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

# Wrap our Keras model in an estimator compatible with scikit_learn
estimator = KerasClassifier(build_fn=create_model, epochs=100, verbose=0)
# Now we can use scikit_learn's cross_val_score to evaluate this model identically to the others
cv_scores = cross_val_score(estimator, all_features, all_classes, cv=10)
cv_scores.mean()
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_test_function.<locals>.test_function at 0x0000021CDEE9D9D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_test_function.<locals>.test_function at 0x0000021CDEAD3D30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 7 calls to <function Model.make_test_function.<locals>.test_function at 0x0000021CDF057550> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 8 calls to <function Model.make_test_function.<locals>.test_function at 0x0000021CE1AF59D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:9 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x0000021CE2EA5D30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:10 out of the last 10 calls to <function Model.make_test_function.<locals>.test_function at 0x0000021CDEDA51F0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 0.9438405811786652

# %% [markdown]
# 94% without even trying too hard! Did you do better? Maybe more neurons, more layers, or Dropout layers would help even more.
